# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot

# %%
df=pd.read_csv('data.csv')
df

# %%
df.info()

# %%
df.head(8)

# %%
df.shape

# %%
a4_dims = (18, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.lineplot(x='Date',y='gold', data=df,ax=ax,)

# %%
sns.show()

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
dataset = pd.read_csv('02 DB Commodities/data.csv',index_col="Date",parse_dates=True)

# %%
dataset.head()
# Out:
#              cocoa  crude_oil     cotton         gold  lean_hogs  copper  \
# Date
# 2018-01-02  1936.0  60.369999  77.500000  1313.699951  70.724998  3.2560
# 2018-01-03  1907.0  61.630001  78.110001  1316.199951  71.050003  3.2370
# 2018-01-04  1905.0  62.009998  79.250000  1319.400024  71.375000  3.2425
# 2018-01-05  1895.0  61.439999  78.010002  1320.300049  71.425003  3.2070
# 2018-01-08  1914.0  61.730000  78.139999  1318.599976  72.974998  3.2010
#
#                  coffe   wheat  live_cattle  natural_gas    platinum  sugar  \
# Date
# 2018-01-02  130.199997  434.75   123.349998        3.056  943.799988  15.33
# 2018-01-03  128.600006  441.00   122.949997        3.008  957.799988  15.31
# 2018-01-04  129.550003  439.75   122.250000        2.880  966.099976  15.25
# 2018-01-05  128.449997  437.50   119.250000        2.795  971.200012  15.08
# 2018-01-08  125.150002  433.25   117.224998        2.835  972.299988  14.78
#
# ...

# %%
dataset.isna().any()
# Out:
# cocoa          False
# crude_oil      False
# cotton         False
# gold           False
# lean_hogs      False
# copper         False
# coffe          False
# wheat          False
# live_cattle    False
# natural_gas    False
# platinum       False
# sugar          False
# silver         False
# corn           False
# oat            False
# rough_rice     False
# soybean        False
# dtype: bool

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 728 entries, 2018-01-02 to 2020-12-31
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cocoa        728 non-null    float64
#  1   crude_oil    728 non-null    float64
#  2   cotton       728 non-null    float64
#  3   gold         728 non-null    float64
#  4   lean_hogs    728 non-null    float64
#  5   copper       728 non-null    float64
#  6   coffe        728 non-null    float64
#  7   wheat        728 non-null    float64
#  8   live_cattle  728 non-null    float64
#  9   natural_gas  728 non-null    float64
#  10  platinum     728 non-null    float64
#  11  sugar        728 non-null    float64
#  12  silver       728 non-null    float64
#  13  corn         728 non-null    float64
#  14  oat          728 non-null    float64
#  15  rough_rice   728 non-null    float64
#  16  soybean      728 non-null    float64
# dtypes: float64(17)
# ...

# %%
dataset['coffe'].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 7 day rolling mean
dataset.rolling(7).mean().head(20)
# Out:
#                   cocoa  crude_oil     cotton         gold  lean_hogs  \
# Date
# 2018-01-02          NaN        NaN        NaN          NaN        NaN
# 2018-01-03          NaN        NaN        NaN          NaN        NaN
# 2018-01-04          NaN        NaN        NaN          NaN        NaN
# 2018-01-05          NaN        NaN        NaN          NaN        NaN
# 2018-01-08          NaN        NaN        NaN          NaN        NaN
# 2018-01-09          NaN        NaN        NaN          NaN        NaN
# 2018-01-10  1913.857143  61.958571  78.430000  1316.757132  71.892858
# 2018-01-11  1912.714286  62.448571  79.165715  1317.742850  71.928573
# 2018-01-12  1913.714286  62.830000  79.675715  1320.200003  72.003572
# 2018-01-16  1917.571429  63.075714  79.987143  1322.485718  72.364286
# 2018-01-17  1930.428571  63.437143  80.577143  1325.014282  72.550000
# 2018-01-18  1940.428571  63.754286  81.218571  1326.071429  72.560715
# ...

# %%
dataset['coffe'].plot(figsize=(16,6))
dataset.rolling(window=30).mean()['coffe'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dataset['coffe: 30 Day Mean'] = dataset['coffe'].rolling(window=30).mean()
dataset[['coffe','coffe: 30 Day Mean']].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Optional specify a minimum number of periods
dataset['coffe'].expanding(min_periods=1).mean().plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
training_set=dataset[['cotton','gold','wheat','corn','oat','coffe']]
training_set=pd.DataFrame(training_set)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 728):
    X_train.append(training_set_scaled[i-60:i,:5])
    y_train.append(training_set_scaled[i, 5:6])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
#X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train
X_train.shape
# Out:
# 60

# %%
y_train
# Out:
# array([[0.60406101],
#        [0.60812186],
#        [0.61421329],
#        [0.6274113 ],
#        [0.62538071],
#        [0.64974629],
#        [0.62842643],
#        [0.63959401],
#        [0.63451786],
#        [0.62233515],
#        [0.56040615],
#        [0.54619301],
#        [0.57360415],
#        [0.56040615],
#        [0.590863  ],
#        [0.61624372],
#        [0.64670058],
#        [0.613198  ],
#        [0.62842643],
#        [0.684264  ],
#        [0.69035544],
#        [0.72994929],
#        [0.70964472],
#        [0.72182743],
#        [0.68629443],
#        [0.64060914],
#        [0.60710672],
#        [0.58578686],
#        [0.60203058],
#        [0.58071072],
#        [0.54822344],
#        [0.53299501],
#        [0.54010158],
#        [0.55228429],
#        [0.55431471],
#        [0.68121829],
#        [0.69441629],
#        [0.66395943],
#        [0.68832501],
#        [0.68527929],
#        [0.68223358],
#        [0.73299501],
#        [0.70761429],
# ...

# %%
#!pip install keras
#!pip install tensorflow
# Out:
# ...
#   Using cached h5py-2.10.0-cp38-cp38-win_amd64.whl (2.5 MB)
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=2afa8b73356dbd57b035ffcc1d7b9794fce749a040455a6148ef9134843ed204
#   Stored in directory: c:\users\raph\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-win_amd64.whl size=33700 sha256=efefbfae1ece5c3ef7befa62c941812427d5b0ccbacca54fe1f0e22dbc8b2ae1
#   Stored in directory: c:\users\raph\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built termcolor wrapt
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ...

# %%
# Part 2 - Building the RNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# Initialising the RNN
regressor = Sequential()

# %%
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1],X_train.shape[2])))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 16s 90ms/step - loss: 0.0978
# Epoch 2/100
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0440
# Epoch 3/100
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0391
# Epoch 4/100
# 21/21 [==============================] - 2s 90ms/step - loss: 0.0360
# Epoch 5/100
# 21/21 [==============================] - 2s 84ms/step - loss: 0.0377
# Epoch 6/100
# 21/21 [==============================] - 2s 83ms/step - loss: 0.0330
# Epoch 7/100
# 21/21 [==============================] - 2s 83ms/step - loss: 0.0341
# Epoch 8/100
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0339
# Epoch 9/100
# 21/21 [==============================] - 2s 80ms/step - loss: 0.0314
# Epoch 10/100
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0317
# Epoch 11/100
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0255
# Epoch 12/100
# ...

# %%
## A patir de acá añadir el test que sería el mes de enero

# %%
# Part 3 - Making the predictions and visualising the results

# Getting the real stock price of 2017
dataset_test = pd.read_csv('02 DB Commodities/test/data_test.csv',index_col="Date",parse_dates=True)

# %%
real_stock_price = dataset_test['coffe'].values
real_stock_price
# Out:
# array([130.19999695, 128.6000061 , 129.55000305, 128.44999695,
#        125.15000153, 125.15000153, 123.94999695, 122.80000305,
#        122.25      , 120.44999695, 123.09999847, 121.09999847,
#        121.25      , 122.55000305, 120.94999695, 122.5       ,
#        123.65000153, 125.15000153, 122.30000305, 121.84999847,
#        121.40000153, 120.40000153, 119.80000305, 122.84999847,
#        123.30000305, 122.84999847, 121.84999847, 121.40000153,
#        122.75      , 122.80000305, 121.75      , 117.94999695,
#        118.19999695, 116.94999695, 119.59999847, 119.44999695,
#        120.5       , 119.94999695, 121.05000305, 122.44999695,
#        120.34999847, 119.19999695, 119.94999695, 119.30000305,
#        119.        , 118.84999847, 118.15000153, 120.44999695,
#        119.94999695, 117.65000153, 116.94999695, 118.34999847,
#        118.94999695, 118.84999847, 119.        , 117.19999695,
#        118.15000153, 118.94999695, 117.75      , 118.15000153,
# ...

# %%
dataset_test.head()
# Out:
#              cocoa  crude_oil     cotton         gold  lean_hogs  copper  \
# Date
# 2018-01-02  1936.0  60.369999  77.500000  1313.699951  70.724998  3.2560
# 2018-01-03  1907.0  61.630001  78.110001  1316.199951  71.050003  3.2370
# 2018-01-04  1905.0  62.009998  79.250000  1319.400024  71.375000  3.2425
# 2018-01-05  1895.0  61.439999  78.010002  1320.300049  71.425003  3.2070
# 2018-01-08  1914.0  61.730000  78.139999  1318.599976  72.974998  3.2010
#
#                  coffe   wheat  live_cattle  natural_gas    platinum  sugar  \
# Date
# 2018-01-02  130.199997  434.75   123.349998        3.056  943.799988  15.33
# 2018-01-03  128.600006  441.00   122.949997        3.008  957.799988  15.31
# 2018-01-04  129.550003  439.75   122.250000        2.880  966.099976  15.25
# 2018-01-05  128.449997  437.50   119.250000        2.795  971.200012  15.08
# 2018-01-08  125.150002  433.25   117.224998        2.835  972.299988  14.78
#
# ...

# %%
dataset_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 728 entries, 2018-01-02 to 2020-12-31
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cocoa        728 non-null    float64
#  1   crude_oil    728 non-null    float64
#  2   cotton       728 non-null    float64
#  3   gold         728 non-null    float64
#  4   lean_hogs    728 non-null    float64
#  5   copper       728 non-null    float64
#  6   coffe        728 non-null    float64
#  7   wheat        728 non-null    float64
#  8   live_cattle  728 non-null    float64
#  9   natural_gas  728 non-null    float64
#  10  platinum     728 non-null    float64
#  11  sugar        728 non-null    float64
#  12  silver       728 non-null    float64
#  13  corn         728 non-null    float64
#  14  oat          728 non-null    float64
#  15  rough_rice   728 non-null    float64
#  16  soybean      728 non-null    float64
# dtypes: float64(17)
# ...

# %%
test_set=dataset_test[['cotton','gold','wheat','corn','oat','coffe']]
test_set=pd.DataFrame(test_set)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 728 entries, 2018-01-02 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cotton  728 non-null    float64
#  1   gold    728 non-null    float64
#  2   wheat   728 non-null    float64
#  3   corn    728 non-null    float64
#  4   oat     728 non-null    float64
#  5   coffe   728 non-null    float64
# dtypes: float64(6)
# memory usage: 39.8 KB

# %%
# Getting the predicted stock price of 2018
dataset_total = pd.concat((dataset['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price=pd.DataFrame(predicted_stock_price)
predicted_stock_price.info()

# %%
# Visualising the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
